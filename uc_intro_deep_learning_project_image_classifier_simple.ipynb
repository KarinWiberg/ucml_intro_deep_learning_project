# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import torch
from torchvision import datasets, transforms, models
from torch import nn, optim
import torch.nn.functional as F
import json
from workspace_utils import active_session
from collections import OrderedDict
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import numpy as np
import timeit
# Out:
# Requirement already satisfied: helper in /opt/conda/lib/python3.6/site-packages (2.5.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.6/site-packages (from helper) (3.12)

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
tune_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# Define the transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                      transforms.RandomResizedCrop(224),
                                      transforms.RandomHorizontalFlip(p=0.25),
                                      transforms.RandomVerticalFlip(p=0.25),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(224),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
tune_data = datasets.ImageFolder(tune_dir, transform=test_transforms)
test_data = datasets.ImageFolder(test_dir, transform=test_transforms)

# Using the image datasets and the trainforms, define the dataloaders
batch_size = 32
trainloader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
tuneloader = torch.utils.data.DataLoader(tune_data, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
# label for classification
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %% [markdown]
# ## Build & Train the Network

# %%
# -- BUILD THE MODEL
# Run on GPU if possible
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu') 

# Load the pre-built and pre-trained model
model = models.vgg16(pretrained=True)

# Freeze the parameters for the pre-trained model, so we dont backprop through them
for param in model.parameters():
    param.requires_grad = False
    
# Define model
from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
    ('fc1', nn.Linear(25088, 512)),
    ('relu1', nn.ReLU()),
    ('do1', nn.Dropout(0.2)),
    ('fc2', nn.Linear(512, 102)),
    ('output', nn.LogSoftmax(dim=1))
]))

# Define the model to be trained
model.classifier = classifier # the model pre-trained model VGG doesnt have .fc but .classifier

# Define loss function
criterion = nn.NLLLoss()

# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
 
# Send model to device
model.to(device)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=512, bias=True)
#     (relu1): ReLU()
#     (do1): Dropout(p=0.2)
#     (fc2): Linear(in_features=512, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
# -- TRAIN THE MODEL
start = timeit.timeit()

# For long running code keep the session active
with active_session():
    
    # Def of variables
    epochs = 10 # nr of trainings
    steps = 0
    running_loss = 0
    print_every = 5
    run_accuracy = 0
    train_losses, tune_losses = [], []
    train_accuracy, tune_accuracy = [], []
    
    # Training
    for epoch in range(epochs): # nr of traning times
        
        for inputs, labels in trainloader: # loop through the data
            
            steps += 1 # train steps
            #print(inputs.size())
            # Move input and label tensors to the default device (GPU if available)
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Zero the gradients - very important
            optimizer.zero_grad()
            
            # Forward pass -> log probabilities
            logps = model.forward(inputs)
            
            # Define loss
            loss = criterion(logps, labels)
            
            # Backward pass
            loss.backward()
            
            # Take a step towards lower loss
            optimizer.step()
            
            # Keep track on the total loss
            running_loss += loss.item()
            
            # calculate the accuracy
            ps = torch.exp(logps) # get the actual probability
            top_p, top_class = ps.topk(1, dim=1) # top probabilities and classes

            equals = top_class == labels.view(*top_class.shape) # check how many images which have the correct classification. 
            # That *top_class.shape is passing all of the items in the top_class.shape into the view function call as separate arguments, without us even needing to know how many arguments are in the list. For example if the top_class has a shape say (32, 1), so *top_class.shape will pass 32, 1 to view function. Now this is as good as passing (top_class.shape[0],top_class.shape[1]). labels.view(top_class.shape[0],top_class.shape[1]) is equal to labels.view(*top_class.shape). The labels.view(*top_class.shape) is very useful because we dont have to know the exact shape for us to reshape them, we just use * and it will pack everything into a list and pass on to the view function for reshaping

            run_accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
            # after getting the top_class of the top_probability from torch.exp(output), we equal the top_class with the images labels (targets) to check if they match or not. The result from this equality is binary values [0,1]. Does this mean that 1 refers to class-label matching and 0 refers to class-label mismatching? Yes
            
            # Tune/evaluate the model every print_every 5 times - OBS makes the model overfit! Move back and tune after each epoch and remove print every.
            if steps % print_every == 0:
                tune_loss = 0
                accuracy = 0
                model.eval() # set model in evaluation mode

                with torch.no_grad(): # reduces memory usage - we dont need to calculate the gradients in evaluation mode

                    for images, labels in tuneloader:

                        # Move images and labels tensors to the default device (GPU if available)
                        images = images.to(device)
                        labels = labels.to(device)

                        # Calculate the loss
                        log_ps = model(images) # log of probability
                        loss = criterion(log_ps, labels)
                        tune_loss += loss.item()

                        # calculate the accuracy
                        ps = torch.exp(log_ps) # get the actual probability
                        top_p, top_class = ps.topk(1, dim=1) # top probabilities and classes

                        equals = top_class == labels.view(*top_class.shape) # check how many images which have the correct classification. 
                        # That *top_class.shape is passing all of the items in the top_class.shape into the view function call as separate arguments, without us even needing to know how many arguments are in the list. For example if the top_class has a shape say (32, 1), so *top_class.shape will pass 32, 1 to view function. Now this is as good as passing (top_class.shape[0],top_class.shape[1]). labels.view(top_class.shape[0],top_class.shape[1]) is equal to labels.view(*top_class.shape). The labels.view(*top_class.shape) is very useful because we dont have to know the exact shape for us to reshape them, we just use * and it will pack everything into a list and pass on to the view function for reshaping

                        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                        # after getting the top_class of the top_probability from torch.exp(output), we equal the top_class with the images labels (targets) to check if they match or not. The result from this equality is binary values [0,1]. Does this mean that 1 refers to class-label matching and 0 refers to class-label mismatching? Yes

                # View model results
                train_losses.append(running_loss/len(trainloader))
                tune_losses.append(tune_loss/len(tuneloader))
                train_accuracy.append(run_accuracy/len(trainloader))
                tune_accuracy.append(accuracy/len(tuneloader))
                        
                print(f"-----------\n"
                      f"Epoch {epoch+1}/{epochs}\n"
                      f"Train loss: {running_loss/print_every:.3f}. " # We have been running print_every nr of epochs
                      f"Tune loss: {tune_loss/len(tuneloader):.3f}\n" # len(X-loader) = nr of images in in a batch
                      f"Train accuracy: {run_accuracy/print_every:.3f}. " 
                      f"Tune accuracy: {accuracy/len(tuneloader):.3f}\n")
            
                running_loss = 0
                tune_loss = 0
                run_accuracy = 0
                
                # Apply the training to the model
                model.train()
                
end = timeit.timeit()
print(f'Tid: {end - start}')
# Out:
# -----------Epoch 1/20
# Train loss: 5.508. Tune loss: 4.893
# Train accuracy: 0.019. Tune accuracy: 0.110
#
# -----------Epoch 1/20
# Train loss: 4.675. Tune loss: 4.203
# Train accuracy: 0.106. Tune accuracy: 0.133
#
# -----------Epoch 1/20
# Train loss: 4.329. Tune loss: 3.965
# Train accuracy: 0.087. Tune accuracy: 0.170
#
# -----------Epoch 1/20
# Train loss: 3.907. Tune loss: 3.705
# Train accuracy: 0.188. Tune accuracy: 0.228
#
# -----------Epoch 1/20
# Train loss: 3.842. Tune loss: 3.463
# Train accuracy: 0.231. Tune accuracy: 0.263
#
# -----------Epoch 1/20
# Train loss: 3.569. Tune loss: 3.254
# Train accuracy: 0.231. Tune accuracy: 0.293
#
# -----------Epoch 1/20
# Train loss: 3.413. Tune loss: 3.061
# Train accuracy: 0.244. Tune accuracy: 0.373
#
# -----------Epoch 1/20
# Train loss: 3.384. Tune loss: 2.869
# Train accuracy: 0.256. Tune accuracy: 0.372
#
# -----------Epoch 1/20
# Train loss: 3.019. Tune loss: 2.658
# Train accuracy: 0.312. Tune accuracy: 0.404
#
# -----------Epoch 1/20
# Train loss: 3.109. Tune loss: 2.594
# Train accuracy: 0.300. Tune accuracy: 0.403
#
# -----------Epoch 1/20
# Train loss: 2.811. Tune loss: 2.425
# Train accuracy: 0.350. Tune accuracy: 0.419
#
# -----------Epoch 1/20
# Train loss: 3.035. Tune loss: 2.302
# Train accuracy: 0.306. Tune accuracy: 0.448
#
# -----------Epoch 1/20
# Train loss: 2.783. Tune loss: 2.145
# Train accuracy: 0.344. Tune accuracy: 0.494
#
# -----------Epoch 1/20
# Train loss: 2.759. Tune loss: 2.005
# Train accuracy: 0.362. Tune accuracy: 0.527
#
# -----------Epoch 1/20
# Train loss: 2.588. Tune loss: 1.886
# Train accuracy: 0.375. Tune accuracy: 0.549
#
# -----------Epoch 1/20
# Train loss: 2.469. Tune loss: 1.794
# Train accuracy: 0.419. Tune accuracy: 0.588
#
# -----------Epoch 1/20
# Train loss: 2.267. Tune loss: 1.753
# Train accuracy: 0.463. Tune accuracy: 0.605
#
# -----------Epoch 1/20
# Train loss: 2.004. Tune loss: 1.727
# Train accuracy: 0.444. Tune accuracy: 0.574
#
# -----------Epoch 1/20
# Train loss: 2.404. Tune loss: 1.701
# Train accuracy: 0.431. Tune accuracy: 0.566
#
# -----------Epoch 1/20
# Train loss: 2.487. Tune loss: 1.613
# Train accuracy: 0.444. Tune accuracy: 0.567
#
# -----------Epoch 1/20
# Train loss: 2.093. Tune loss: 1.532
# Train accuracy: 0.506. Tune accuracy: 0.604
#
# -----------Epoch 1/20
# Train loss: 2.121. Tune loss: 1.488
# Train accuracy: 0.469. Tune accuracy: 0.617
#
# -----------Epoch 1/20
# Train loss: 2.145. Tune loss: 1.449
# Train accuracy: 0.481. Tune accuracy: 0.615
#
# -----------Epoch 1/20
# Train loss: 2.048. Tune loss: 1.366
# Train accuracy: 0.444. Tune accuracy: 0.638
#
# -----------Epoch 1/20
# Train loss: 1.943. Tune loss: 1.373
# Train accuracy: 0.544. Tune accuracy: 0.651
#
# -----------Epoch 1/20
# Train loss: 2.012. Tune loss: 1.318
# Train accuracy: 0.494. Tune accuracy: 0.643
#
# -----------Epoch 1/20
# Train loss: 2.099. Tune loss: 1.233
# Train accuracy: 0.487. Tune accuracy: 0.668
#
# -----------Epoch 1/20
# Train loss: 1.971. Tune loss: 1.229
# Train accuracy: 0.519. Tune accuracy: 0.682
#
# -----------Epoch 1/20
# Train loss: 1.792. Tune loss: 1.178
# Train accuracy: 0.531. Tune accuracy: 0.691
#
# -----------Epoch 1/20
# Train loss: 2.021. Tune loss: 1.190
# Train accuracy: 0.481. Tune accuracy: 0.691
#
# -----------Epoch 1/20
# Train loss: 1.785. Tune loss: 1.145
# Train accuracy: 0.519. Tune accuracy: 0.696
#
# -----------Epoch 1/20
# Train loss: 1.744. Tune loss: 1.090
# Train accuracy: 0.550. Tune accuracy: 0.705
#
# -----------Epoch 1/20
# Train loss: 1.718. Tune loss: 1.103
# Train accuracy: 0.525. Tune accuracy: 0.702
#
# -----------Epoch 1/20
# Train loss: 1.619. Tune loss: 1.060
# Train accuracy: 0.537. Tune accuracy: 0.715
#
# -----------Epoch 1/20
# Train loss: 1.684. Tune loss: 1.027
# Train accuracy: 0.575. Tune accuracy: 0.717
#
# -----------Epoch 1/20
# Train loss: 1.649. Tune loss: 1.055
# Train accuracy: 0.537. Tune accuracy: 0.700
#
# -----------Epoch 1/20
# Train loss: 1.820. Tune loss: 0.970
# Train accuracy: 0.544. Tune accuracy: 0.737
#
# -----------Epoch 1/20
# Train loss: 1.411. Tune loss: 1.021
# Train accuracy: 0.631. Tune accuracy: 0.714
#
# -----------Epoch 1/20
# Train loss: 1.534. Tune loss: 0.988
# Train accuracy: 0.594. Tune accuracy: 0.722
#
# -----------Epoch 1/20
# Train loss: 1.428. Tune loss: 1.007
# Train accuracy: 0.600. Tune accuracy: 0.730
#
# -----------Epoch 1/20
# Train loss: 1.529. Tune loss: 1.030
# Train accuracy: 0.598. Tune accuracy: 0.732
#
# -----------Epoch 2/20
# Train loss: 1.506. Tune loss: 0.933
# Train accuracy: 0.569. Tune accuracy: 0.757
#
# -----------Epoch 2/20
# Train loss: 1.573. Tune loss: 0.987
# Train accuracy: 0.625. Tune accuracy: 0.742
#
# -----------Epoch 2/20
# Train loss: 1.333. Tune loss: 0.951
# Train accuracy: 0.675. Tune accuracy: 0.755
#
# -----------Epoch 2/20
# Train loss: 1.238. Tune loss: 0.895
# Train accuracy: 0.656. Tune accuracy: 0.758
#
# -----------Epoch 2/20
# Train loss: 1.204. Tune loss: 0.850
# Train accuracy: 0.669. Tune accuracy: 0.762
#
# -----------Epoch 2/20
# Train loss: 1.514. Tune loss: 0.877
# Train accuracy: 0.556. Tune accuracy: 0.749
#
# -----------Epoch 2/20
# Train loss: 1.426. Tune loss: 0.854
# Train accuracy: 0.637. Tune accuracy: 0.755
#
# -----------Epoch 2/20
# Train loss: 1.364. Tune loss: 0.832
# Train accuracy: 0.600. Tune accuracy: 0.757
#
# -----------Epoch 2/20
# Train loss: 1.675. Tune loss: 0.850
# Train accuracy: 0.588. Tune accuracy: 0.777
#
# -----------Epoch 2/20
# Train loss: 1.434. Tune loss: 0.853
# Train accuracy: 0.588. Tune accuracy: 0.770
#
# -----------Epoch 2/20
# Train loss: 1.270. Tune loss: 0.844
# Train accuracy: 0.700. Tune accuracy: 0.767
#
# -----------Epoch 2/20
# Train loss: 1.432. Tune loss: 0.862
# Train accuracy: 0.613. Tune accuracy: 0.772
#
# -----------Epoch 2/20
# Train loss: 1.373. Tune loss: 0.908
# Train accuracy: 0.662. Tune accuracy: 0.757
#
# -----------Epoch 2/20
# Train loss: 1.386. Tune loss: 0.892
# Train accuracy: 0.662. Tune accuracy: 0.753
#
# -----------Epoch 2/20
# Train loss: 1.386. Tune loss: 0.899
# Train accuracy: 0.625. Tune accuracy: 0.756
#
# -----------Epoch 2/20
# Train loss: 1.340. Tune loss: 0.935
# Train accuracy: 0.637. Tune accuracy: 0.753
#
# -----------Epoch 2/20
# Train loss: 1.623. Tune loss: 0.868
# Train accuracy: 0.613. Tune accuracy: 0.783
#
# -----------Epoch 2/20
# Train loss: 1.609. Tune loss: 0.849
# Train accuracy: 0.544. Tune accuracy: 0.773
#
# -----------Epoch 2/20
# Train loss: 1.282. Tune loss: 0.831
# Train accuracy: 0.681. Tune accuracy: 0.768
#
# -----------Epoch 2/20
# Train loss: 1.430. Tune loss: 0.758
# Train accuracy: 0.637. Tune accuracy: 0.804
#
# -----------Epoch 2/20
# Train loss: 1.100. Tune loss: 0.731
# Train accuracy: 0.681. Tune accuracy: 0.812
#
# -----------Epoch 2/20
# Train loss: 1.307. Tune loss: 0.706
# Train accuracy: 0.656. Tune accuracy: 0.808
#
# -----------Epoch 2/20
# Train loss: 1.304. Tune loss: 0.744
# Train accuracy: 0.644. Tune accuracy: 0.794
#
# -----------Epoch 2/20
# Train loss: 1.507. Tune loss: 0.783
# Train accuracy: 0.613. Tune accuracy: 0.779
#
# -----------Epoch 2/20
# Train loss: 1.217. Tune loss: 0.747
# Train accuracy: 0.650. Tune accuracy: 0.786
#
# -----------Epoch 2/20
# Train loss: 1.460. Tune loss: 0.805
# Train accuracy: 0.637. Tune accuracy: 0.775
#
# -----------Epoch 2/20
# Train loss: 1.327. Tune loss: 0.834
# Train accuracy: 0.631. Tune accuracy: 0.774
#
# -----------Epoch 2/20
# Train loss: 1.348. Tune loss: 0.810
# Train accuracy: 0.606. Tune accuracy: 0.783
#
# -----------Epoch 2/20
# Train loss: 1.300. Tune loss: 0.724
# Train accuracy: 0.650. Tune accuracy: 0.806
#
# -----------Epoch 2/20
# Train loss: 1.256. Tune loss: 0.697
# Train accuracy: 0.656. Tune accuracy: 0.808
#
# -----------Epoch 2/20
# Train loss: 1.385. Tune loss: 0.705
# Train accuracy: 0.637. Tune accuracy: 0.802
#
# -----------Epoch 2/20
# Train loss: 1.149. Tune loss: 0.771
# Train accuracy: 0.662. Tune accuracy: 0.776
#
# -----------Epoch 2/20
# Train loss: 1.330. Tune loss: 0.799
# Train accuracy: 0.669. Tune accuracy: 0.795
#
# -----------Epoch 2/20
# Train loss: 1.349. Tune loss: 0.766
# Train accuracy: 0.688. Tune accuracy: 0.802
#
# -----------Epoch 2/20
# Train loss: 1.345. Tune loss: 0.705
# Train accuracy: 0.600. Tune accuracy: 0.807
#
# -----------Epoch 2/20
# Train loss: 1.330. Tune loss: 0.698
# Train accuracy: 0.644. Tune accuracy: 0.796
#
# -----------Epoch 2/20
# Train loss: 1.009. Tune loss: 0.750
# Train accuracy: 0.731. Tune accuracy: 0.773
#
# -----------Epoch 2/20
# Train loss: 1.371. Tune loss: 0.707
# Train accuracy: 0.606. Tune accuracy: 0.793
#
# -----------Epoch 2/20
# Train loss: 1.139. Tune loss: 0.744
# Train accuracy: 0.719. Tune accuracy: 0.790
# -----------Epoch 2/20
# Train loss: 1.328. Tune loss: 0.756
# Train accuracy: 0.669. Tune accuracy: 0.787
#
# -----------Epoch 2/20
# Train loss: 1.366. Tune loss: 0.746
# Train accuracy: 0.669. Tune accuracy: 0.795
#
# -----------Epoch 3/20
# Train loss: 1.076. Tune loss: 0.768
# Train accuracy: 0.669. Tune accuracy: 0.771
#
# -----------Epoch 3/20
# Train loss: 1.216. Tune loss: 0.725
# Train accuracy: 0.694. Tune accuracy: 0.787
#
# -----------Epoch 3/20
# Train loss: 1.298. Tune loss: 0.674
# Train accuracy: 0.656. Tune accuracy: 0.803
#
# -----------Epoch 3/20
# Train loss: 1.174. Tune loss: 0.710
# Train accuracy: 0.681. Tune accuracy: 0.809
#
# -----------Epoch 3/20
# Train loss: 1.117. Tune loss: 0.753
# Train accuracy: 0.681. Tune accuracy: 0.793
#
# -----------Epoch 3/20
# Train loss: 1.394. Tune loss: 0.748
# Train accuracy: 0.681. Tune accuracy: 0.801
#
# -----------Epoch 3/20
# Train loss: 1.174. Tune loss: 0.787
# Train accuracy: 0.662. Tune accuracy: 0.786
#
# -----------Epoch 3/20
# Train loss: 1.231. Tune loss: 0.799
# Train accuracy: 0.725. Tune accuracy: 0.780
#
# -----------Epoch 3/20
# Train loss: 1.083. Tune loss: 0.777
# Train accuracy: 0.706. Tune accuracy: 0.772
#
# -----------Epoch 3/20
# Train loss: 1.296. Tune loss: 0.786
# Train accuracy: 0.644. Tune accuracy: 0.776
#
# -----------Epoch 3/20
# Train loss: 1.265. Tune loss: 0.794
# Train accuracy: 0.650. Tune accuracy: 0.774
#
# -----------Epoch 3/20
# Train loss: 1.271. Tune loss: 0.689
# Train accuracy: 0.725. Tune accuracy: 0.802
#
# -----------Epoch 3/20
# Train loss: 1.227. Tune loss: 0.634
# Train accuracy: 0.669. Tune accuracy: 0.824
#
# -----------Epoch 3/20
# Train loss: 1.132. Tune loss: 0.658
# Train accuracy: 0.725. Tune accuracy: 0.815
#
# -----------Epoch 3/20
# Train loss: 1.147. Tune loss: 0.718
# Train accuracy: 0.650. Tune accuracy: 0.798
#
# -----------Epoch 3/20
# Train loss: 1.246. Tune loss: 0.667
# Train accuracy: 0.619. Tune accuracy: 0.813
#
# -----------Epoch 3/20
# Train loss: 1.083. Tune loss: 0.659
# Train accuracy: 0.694. Tune accuracy: 0.804
#
# -----------Epoch 3/20
# Train loss: 1.091. Tune loss: 0.612
# Train accuracy: 0.713. Tune accuracy: 0.827
#
# -----------Epoch 3/20
# Train loss: 0.946. Tune loss: 0.649
# Train accuracy: 0.769. Tune accuracy: 0.809
#
# -----------Epoch 3/20
# Train loss: 1.088. Tune loss: 0.657
# Train accuracy: 0.731. Tune accuracy: 0.812
#
# -----------Epoch 3/20
# Train loss: 0.914. Tune loss: 0.678
# Train accuracy: 0.781. Tune accuracy: 0.813
#
# -----------Epoch 3/20
# Train loss: 1.353. Tune loss: 0.695
# Train accuracy: 0.669. Tune accuracy: 0.815
#
# -----------Epoch 3/20
# Train loss: 1.167. Tune loss: 0.654
# Train accuracy: 0.644. Tune accuracy: 0.817
#
# -----------Epoch 3/20
# Train loss: 1.095. Tune loss: 0.703
# Train accuracy: 0.700. Tune accuracy: 0.810
#
# -----------Epoch 3/20
# Train loss: 0.891. Tune loss: 0.723
# Train accuracy: 0.750. Tune accuracy: 0.805
#
# -----------Epoch 3/20
# Train loss: 1.080. Tune loss: 0.708
# Train accuracy: 0.706. Tune accuracy: 0.803
#
# -----------Epoch 3/20
# Train loss: 1.422. Tune loss: 0.628
# Train accuracy: 0.619. Tune accuracy: 0.823
#
# -----------Epoch 3/20
# Train loss: 1.219. Tune loss: 0.618
# Train accuracy: 0.694. Tune accuracy: 0.820
#
# -----------Epoch 3/20
# Train loss: 1.306. Tune loss: 0.609
# Train accuracy: 0.669. Tune accuracy: 0.816
#
# -----------Epoch 3/20
# Train loss: 1.001. Tune loss: 0.632
# Train accuracy: 0.731. Tune accuracy: 0.814
#
# -----------Epoch 3/20
# Train loss: 0.956. Tune loss: 0.675
# Train accuracy: 0.719. Tune accuracy: 0.808
#
# -----------Epoch 3/20
# Train loss: 1.110. Tune loss: 0.629
# Train accuracy: 0.700. Tune accuracy: 0.812
#
# -----------Epoch 3/20
# Train loss: 1.535. Tune loss: 0.563
# Train accuracy: 0.600. Tune accuracy: 0.833
#
# -----------Epoch 3/20
# Train loss: 1.029. Tune loss: 0.572
# Train accuracy: 0.713. Tune accuracy: 0.822
#
# -----------Epoch 3/20
# Train loss: 1.166. Tune loss: 0.600
# Train accuracy: 0.706. Tune accuracy: 0.816
#
# -----------Epoch 3/20
# Train loss: 1.059. Tune loss: 0.591
# Train accuracy: 0.713. Tune accuracy: 0.828
#
# -----------Epoch 3/20
# Train loss: 1.240. Tune loss: 0.595
# Train accuracy: 0.694. Tune accuracy: 0.824
#
# -----------Epoch 3/20
# Train loss: 0.776. Tune loss: 0.633
# Train accuracy: 0.738. Tune accuracy: 0.810
#
# -----------Epoch 3/20
# Train loss: 1.197. Tune loss: 0.666
# Train accuracy: 0.700. Tune accuracy: 0.816
#
# -----------Epoch 3/20
# Train loss: 0.925. Tune loss: 0.657
# Train accuracy: 0.756. Tune accuracy: 0.819
#
# -----------Epoch 3/20
# Train loss: 1.121. Tune loss: 0.644
# Train accuracy: 0.683. Tune accuracy: 0.824
#
# -----------Epoch 4/20
# Train loss: 0.879. Tune loss: 0.577
# Train accuracy: 0.756. Tune accuracy: 0.844
#
# -----------Epoch 4/20
# Train loss: 1.112. Tune loss: 0.550
# Train accuracy: 0.719. Tune accuracy: 0.850
#
# -----------Epoch 4/20
# Train loss: 0.836. Tune loss: 0.542
# Train accuracy: 0.769. Tune accuracy: 0.852
#
# -----------Epoch 4/20
# Train loss: 0.835. Tune loss: 0.586
# Train accuracy: 0.775. Tune accuracy: 0.837
#
# -----------Epoch 4/20
# Train loss: 1.118. Tune loss: 0.583
# Train accuracy: 0.694. Tune accuracy: 0.833
#
# -----------Epoch 4/20
# Train loss: 1.018. Tune loss: 0.557
# Train accuracy: 0.700. Tune accuracy: 0.852
#
# -----------Epoch 4/20
# Train loss: 0.902. Tune loss: 0.550
# Train accuracy: 0.700. Tune accuracy: 0.859
#
# -----------Epoch 4/20
# Train loss: 0.894. Tune loss: 0.570
# Train accuracy: 0.738. Tune accuracy: 0.844
#
# -----------Epoch 4/20
# Train loss: 0.925. Tune loss: 0.578
# Train accuracy: 0.706. Tune accuracy: 0.847
#
# -----------Epoch 4/20
# Train loss: 1.023. Tune loss: 0.566
# Train accuracy: 0.744. Tune accuracy: 0.853
#
# -----------Epoch 4/20
# Train loss: 0.969. Tune loss: 0.581
# Train accuracy: 0.738. Tune accuracy: 0.846
#
# -----------Epoch 4/20
# Train loss: 1.264. Tune loss: 0.599
# Train accuracy: 0.662. Tune accuracy: 0.845
#
# -----------Epoch 4/20
# Train loss: 1.239. Tune loss: 0.606
# Train accuracy: 0.688. Tune accuracy: 0.834
#
# -----------Epoch 4/20
# Train loss: 1.075. Tune loss: 0.627
# Train accuracy: 0.681. Tune accuracy: 0.832
#
# -----------Epoch 4/20
# Train loss: 1.306. Tune loss: 0.636
# Train accuracy: 0.650. Tune accuracy: 0.833
#
# -----------Epoch 4/20
# Train loss: 1.134. Tune loss: 0.646
# Train accuracy: 0.669. Tune accuracy: 0.836
#
# -----------Epoch 4/20
# Train loss: 0.841. Tune loss: 0.638
# Train accuracy: 0.738. Tune accuracy: 0.843
#
# -----------Epoch 4/20
# Train loss: 1.192. Tune loss: 0.622
# Train accuracy: 0.731. Tune accuracy: 0.841
#
# -----------Epoch 4/20
# Train loss: 1.039. Tune loss: 0.602
# Train accuracy: 0.750. Tune accuracy: 0.842
#
# -----------Epoch 4/20
# Train loss: 0.971. Tune loss: 0.593
# Train accuracy: 0.713. Tune accuracy: 0.839
#
# -----------Epoch 4/20
# Train loss: 1.119. Tune loss: 0.651
# Train accuracy: 0.725. Tune accuracy: 0.827
#
# -----------Epoch 4/20
# Train loss: 1.019. Tune loss: 0.668
# Train accuracy: 0.706. Tune accuracy: 0.819
#
# -----------Epoch 4/20
# Train loss: 1.178. Tune loss: 0.640
# Train accuracy: 0.650. Tune accuracy: 0.822
#
# -----------Epoch 4/20
# Train loss: 1.209. Tune loss: 0.602
# Train accuracy: 0.662. Tune accuracy: 0.828
#
# -----------Epoch 4/20
# Train loss: 1.047. Tune loss: 0.638
# Train accuracy: 0.700. Tune accuracy: 0.824
#
# -----------Epoch 4/20
# Train loss: 1.148. Tune loss: 0.612
# Train accuracy: 0.694. Tune accuracy: 0.836
#
# -----------Epoch 4/20
# Train loss: 1.007. Tune loss: 0.591
# Train accuracy: 0.738. Tune accuracy: 0.844
#
# -----------Epoch 4/20
# Train loss: 1.046. Tune loss: 0.593
# Train accuracy: 0.731. Tune accuracy: 0.843
#
# -----------Epoch 4/20
# Train loss: 1.274. Tune loss: 0.642
# Train accuracy: 0.700. Tune accuracy: 0.839
#
# -----------Epoch 4/20
# Train loss: 0.934. Tune loss: 0.635
# Train accuracy: 0.756. Tune accuracy: 0.840
#
# -----------Epoch 4/20
# Train loss: 1.200. Tune loss: 0.640
# Train accuracy: 0.694. Tune accuracy: 0.830
#
# -----------Epoch 4/20
# Train loss: 1.005. Tune loss: 0.628
# Train accuracy: 0.700. Tune accuracy: 0.828
#
# -----------Epoch 4/20
# Train loss: 1.352. Tune loss: 0.599
# Train accuracy: 0.594. Tune accuracy: 0.845
#
# -----------Epoch 4/20
# Train loss: 1.044. Tune loss: 0.595
# Train accuracy: 0.694. Tune accuracy: 0.839
#
# -----------Epoch 4/20
# Train loss: 0.977. Tune loss: 0.646
# Train accuracy: 0.744. Tune accuracy: 0.826
#
# -----------Epoch 4/20
# Train loss: 1.008. Tune loss: 0.642
# Train accuracy: 0.713. Tune accuracy: 0.827
#
# -----------Epoch 4/20
# Train loss: 1.174. Tune loss: 0.630
# Train accuracy: 0.662. Tune accuracy: 0.837
# -----------Epoch 4/20
# Train loss: 1.000. Tune loss: 0.606
# Train accuracy: 0.700. Tune accuracy: 0.838
#
# -----------Epoch 4/20
# Train loss: 1.007. Tune loss: 0.621
# Train accuracy: 0.756. Tune accuracy: 0.840
#
# -----------Epoch 4/20
# Train loss: 0.860. Tune loss: 0.668
# Train accuracy: 0.769. Tune accuracy: 0.824
#
# -----------Epoch 4/20
# Train loss: 0.996. Tune loss: 0.654
# Train accuracy: 0.725. Tune accuracy: 0.824
#
# -----------Epoch 5/20
# Train loss: 0.946. Tune loss: 0.666
# Train accuracy: 0.744. Tune accuracy: 0.810
#
# -----------Epoch 5/20
# Train loss: 1.034. Tune loss: 0.692
# Train accuracy: 0.744. Tune accuracy: 0.814
#
# -----------Epoch 5/20
# Train loss: 1.037. Tune loss: 0.638
# Train accuracy: 0.706. Tune accuracy: 0.826
#
# -----------Epoch 5/20
# Train loss: 1.121. Tune loss: 0.608
# Train accuracy: 0.719. Tune accuracy: 0.835
#
# -----------Epoch 5/20
# Train loss: 1.017. Tune loss: 0.583
# Train accuracy: 0.731. Tune accuracy: 0.845
#
# -----------Epoch 5/20
# Train loss: 1.044. Tune loss: 0.549
# Train accuracy: 0.713. Tune accuracy: 0.856
#
# -----------Epoch 5/20
# Train loss: 0.830. Tune loss: 0.538
# Train accuracy: 0.769. Tune accuracy: 0.854
#
# -----------Epoch 5/20
# Train loss: 0.871. Tune loss: 0.547
# Train accuracy: 0.762. Tune accuracy: 0.846
#
# -----------Epoch 5/20
# Train loss: 0.750. Tune loss: 0.565
# Train accuracy: 0.769. Tune accuracy: 0.847
#
# -----------Epoch 5/20
# Train loss: 0.933. Tune loss: 0.524
# Train accuracy: 0.700. Tune accuracy: 0.851
#
# -----------Epoch 5/20
# Train loss: 0.995. Tune loss: 0.516
# Train accuracy: 0.694. Tune accuracy: 0.859
#
# -----------Epoch 5/20
# Train loss: 1.115. Tune loss: 0.563
# Train accuracy: 0.700. Tune accuracy: 0.846
#
# -----------Epoch 5/20
# Train loss: 0.883. Tune loss: 0.592
# Train accuracy: 0.731. Tune accuracy: 0.833
#
# -----------Epoch 5/20
# Train loss: 1.099. Tune loss: 0.618
# Train accuracy: 0.656. Tune accuracy: 0.825
#
# -----------Epoch 5/20
# Train loss: 0.766. Tune loss: 0.639
# Train accuracy: 0.806. Tune accuracy: 0.832
#
# -----------Epoch 5/20
# Train loss: 1.126. Tune loss: 0.626
# Train accuracy: 0.706. Tune accuracy: 0.843
#
# -----------Epoch 5/20
# Train loss: 0.984. Tune loss: 0.634
# Train accuracy: 0.731. Tune accuracy: 0.847
#
# -----------Epoch 5/20
# Train loss: 0.813. Tune loss: 0.699
# Train accuracy: 0.781. Tune accuracy: 0.822
#
# -----------Epoch 5/20
# Train loss: 1.389. Tune loss: 0.655
# Train accuracy: 0.675. Tune accuracy: 0.827
#
# -----------Epoch 5/20
# Train loss: 0.945. Tune loss: 0.669
# Train accuracy: 0.769. Tune accuracy: 0.822
#
# -----------Epoch 5/20
# Train loss: 1.068. Tune loss: 0.634
# Train accuracy: 0.694. Tune accuracy: 0.830
#
# -----------Epoch 5/20
# Train loss: 0.958. Tune loss: 0.602
# Train accuracy: 0.731. Tune accuracy: 0.828
#
# -----------Epoch 5/20
# Train loss: 1.014. Tune loss: 0.611
# Train accuracy: 0.700. Tune accuracy: 0.832
#
# -----------Epoch 5/20
# Train loss: 0.816. Tune loss: 0.637
# Train accuracy: 0.756. Tune accuracy: 0.827
#
# -----------Epoch 5/20
# Train loss: 0.944. Tune loss: 0.626
# Train accuracy: 0.750. Tune accuracy: 0.836
#
# -----------Epoch 5/20
# Train loss: 0.990. Tune loss: 0.629
# Train accuracy: 0.744. Tune accuracy: 0.835
#
# -----------Epoch 5/20
# Train loss: 1.018. Tune loss: 0.566
# Train accuracy: 0.719. Tune accuracy: 0.849
#
# -----------Epoch 5/20
# Train loss: 0.883. Tune loss: 0.581
# Train accuracy: 0.731. Tune accuracy: 0.845
#
# -----------Epoch 5/20
# Train loss: 1.163. Tune loss: 0.618
# Train accuracy: 0.713. Tune accuracy: 0.842
#
# -----------Epoch 5/20
# Train loss: 0.932. Tune loss: 0.647
# Train accuracy: 0.775. Tune accuracy: 0.824
#
# -----------Epoch 5/20
# Train loss: 0.874. Tune loss: 0.640
# Train accuracy: 0.750. Tune accuracy: 0.829
#
# -----------Epoch 5/20
# Train loss: 1.102. Tune loss: 0.632
# Train accuracy: 0.681. Tune accuracy: 0.840
#
# -----------Epoch 5/20
# Train loss: 1.002. Tune loss: 0.643
# Train accuracy: 0.731. Tune accuracy: 0.842
#
# -----------Epoch 5/20
# Train loss: 1.107. Tune loss: 0.671
# Train accuracy: 0.706. Tune accuracy: 0.818
#
# -----------Epoch 5/20
# Train loss: 1.026. Tune loss: 0.683
# Train accuracy: 0.694. Tune accuracy: 0.821
#
# -----------Epoch 5/20
# Train loss: 1.228. Tune loss: 0.615
# Train accuracy: 0.681. Tune accuracy: 0.840
#
# -----------Epoch 5/20
# Train loss: 0.761. Tune loss: 0.594
# Train accuracy: 0.794. Tune accuracy: 0.847
#
# -----------Epoch 5/20
# Train loss: 0.927. Tune loss: 0.630
# Train accuracy: 0.706. Tune accuracy: 0.845
#
# -----------Epoch 5/20
# Train loss: 1.127. Tune loss: 0.648
# Train accuracy: 0.650. Tune accuracy: 0.828
#
# -----------Epoch 5/20
# Train loss: 1.350. Tune loss: 0.661
# Train accuracy: 0.656. Tune accuracy: 0.832
#
# -----------Epoch 5/20
# Train loss: 0.865. Tune loss: 0.666
# Train accuracy: 0.785. Tune accuracy: 0.830
#
# -----------Epoch 6/20
# Train loss: 1.082. Tune loss: 0.604
# Train accuracy: 0.731. Tune accuracy: 0.848
#
# -----------Epoch 6/20
# Train loss: 0.901. Tune loss: 0.602
# Train accuracy: 0.731. Tune accuracy: 0.848
#
# -----------Epoch 6/20
# Train loss: 0.817. Tune loss: 0.606
# Train accuracy: 0.775. Tune accuracy: 0.843
#
# -----------Epoch 6/20
# Train loss: 0.665. Tune loss: 0.601
# Train accuracy: 0.800. Tune accuracy: 0.833
#
# -----------Epoch 6/20
# Train loss: 0.789. Tune loss: 0.598
# Train accuracy: 0.781. Tune accuracy: 0.823
#
# -----------Epoch 6/20
# Train loss: 1.197. Tune loss: 0.634
# Train accuracy: 0.725. Tune accuracy: 0.828
#
# -----------Epoch 6/20
# Train loss: 0.973. Tune loss: 0.633
# Train accuracy: 0.719. Tune accuracy: 0.836
#
# -----------Epoch 6/20
# Train loss: 1.076. Tune loss: 0.655
# Train accuracy: 0.725. Tune accuracy: 0.818
#
# -----------Epoch 6/20
# Train loss: 1.156. Tune loss: 0.640
# Train accuracy: 0.700. Tune accuracy: 0.840
#
# -----------Epoch 6/20
# Train loss: 1.129. Tune loss: 0.601
# Train accuracy: 0.725. Tune accuracy: 0.839
#
# -----------Epoch 6/20
# Train loss: 0.859. Tune loss: 0.593
# Train accuracy: 0.787. Tune accuracy: 0.844
#
# -----------Epoch 6/20
# Train loss: 1.058. Tune loss: 0.541
# Train accuracy: 0.744. Tune accuracy: 0.857
#
# -----------Epoch 6/20
# Train loss: 1.091. Tune loss: 0.525
# Train accuracy: 0.719. Tune accuracy: 0.853
#
# -----------Epoch 6/20
# Train loss: 0.851. Tune loss: 0.536
# Train accuracy: 0.756. Tune accuracy: 0.849
#
# -----------Epoch 6/20
# Train loss: 1.134. Tune loss: 0.551
# Train accuracy: 0.719. Tune accuracy: 0.852
#
# -----------Epoch 6/20
# Train loss: 1.033. Tune loss: 0.596
# Train accuracy: 0.694. Tune accuracy: 0.851
#
# -----------Epoch 6/20
# Train loss: 0.903. Tune loss: 0.691
# Train accuracy: 0.756. Tune accuracy: 0.828
#
# -----------Epoch 6/20
# Train loss: 0.872. Tune loss: 0.644
# Train accuracy: 0.738. Tune accuracy: 0.835
#
# -----------Epoch 6/20
# Train loss: 1.282. Tune loss: 0.580
# Train accuracy: 0.713. Tune accuracy: 0.850
#
# -----------Epoch 6/20
# Train loss: 0.999. Tune loss: 0.569
# Train accuracy: 0.700. Tune accuracy: 0.843
#
# -----------Epoch 6/20
# Train loss: 0.965. Tune loss: 0.603
# Train accuracy: 0.719. Tune accuracy: 0.845
#
# -----------Epoch 6/20
# Train loss: 0.954. Tune loss: 0.633
# Train accuracy: 0.762. Tune accuracy: 0.843
#
# -----------Epoch 6/20
# Train loss: 0.753. Tune loss: 0.663
# Train accuracy: 0.806. Tune accuracy: 0.839
#
# -----------Epoch 6/20
# Train loss: 0.993. Tune loss: 0.626
# Train accuracy: 0.706. Tune accuracy: 0.840
#
# -----------Epoch 6/20
# Train loss: 0.987. Tune loss: 0.571
# Train accuracy: 0.675. Tune accuracy: 0.843
#
# -----------Epoch 6/20
# Train loss: 1.240. Tune loss: 0.623
# Train accuracy: 0.681. Tune accuracy: 0.839
#
# -----------Epoch 6/20
# Train loss: 1.117. Tune loss: 0.674
# Train accuracy: 0.675. Tune accuracy: 0.833
#
# -----------Epoch 6/20
# Train loss: 0.937. Tune loss: 0.665
# Train accuracy: 0.769. Tune accuracy: 0.836
#
# -----------Epoch 6/20
# Train loss: 1.101. Tune loss: 0.611
# Train accuracy: 0.731. Tune accuracy: 0.849
#
# -----------Epoch 6/20
# Train loss: 1.086. Tune loss: 0.608
# Train accuracy: 0.675. Tune accuracy: 0.846
#
# -----------Epoch 6/20
# Train loss: 1.018. Tune loss: 0.618
# Train accuracy: 0.738. Tune accuracy: 0.831
#
# -----------Epoch 6/20
# Train loss: 1.053. Tune loss: 0.606
# Train accuracy: 0.738. Tune accuracy: 0.841
#
# -----------Epoch 6/20
# Train loss: 1.102. Tune loss: 0.585
# Train accuracy: 0.706. Tune accuracy: 0.852
#
# -----------Epoch 6/20
# Train loss: 0.884. Tune loss: 0.603
# Train accuracy: 0.750. Tune accuracy: 0.855
#
# -----------Epoch 6/20
# Train loss: 0.949. Tune loss: 0.618
# Train accuracy: 0.744. Tune accuracy: 0.843
# -----------Epoch 6/20
# Train loss: 1.294. Tune loss: 0.602
# Train accuracy: 0.700. Tune accuracy: 0.846
#
# -----------Epoch 6/20
# Train loss: 1.111. Tune loss: 0.585
# Train accuracy: 0.656. Tune accuracy: 0.835
#
# -----------Epoch 6/20
# Train loss: 0.946. Tune loss: 0.588
# Train accuracy: 0.731. Tune accuracy: 0.833
#
# -----------Epoch 6/20
# Train loss: 1.113. Tune loss: 0.565
# Train accuracy: 0.662. Tune accuracy: 0.845
#
# -----------Epoch 6/20
# Train loss: 1.105. Tune loss: 0.555
# Train accuracy: 0.725. Tune accuracy: 0.848
#
# -----------Epoch 6/20
# Train loss: 1.087. Tune loss: 0.555
# Train accuracy: 0.727. Tune accuracy: 0.859
#
# -----------Epoch 7/20
# Train loss: 0.954. Tune loss: 0.567
# Train accuracy: 0.762. Tune accuracy: 0.849
#
# -----------Epoch 7/20
# Train loss: 0.785. Tune loss: 0.557
# Train accuracy: 0.762. Tune accuracy: 0.852
#
# -----------Epoch 7/20
# Train loss: 0.806. Tune loss: 0.549
# Train accuracy: 0.762. Tune accuracy: 0.848
#
# -----------Epoch 7/20
# Train loss: 1.096. Tune loss: 0.554
# Train accuracy: 0.719. Tune accuracy: 0.858
#
# -----------Epoch 7/20
# Train loss: 0.867. Tune loss: 0.569
# Train accuracy: 0.731. Tune accuracy: 0.848
#
# -----------Epoch 7/20
# Train loss: 0.887. Tune loss: 0.568
# Train accuracy: 0.806. Tune accuracy: 0.849
#
# -----------Epoch 7/20
# Train loss: 0.951. Tune loss: 0.583
# Train accuracy: 0.725. Tune accuracy: 0.845
#
# -----------Epoch 7/20
# Train loss: 0.891. Tune loss: 0.625
# Train accuracy: 0.775. Tune accuracy: 0.843
#
# -----------Epoch 7/20
# Train loss: 1.147. Tune loss: 0.594
# Train accuracy: 0.688. Tune accuracy: 0.843
#
# -----------Epoch 7/20
# Train loss: 0.815. Tune loss: 0.572
# Train accuracy: 0.762. Tune accuracy: 0.848
#
# -----------Epoch 7/20
# Train loss: 0.825. Tune loss: 0.605
# Train accuracy: 0.744. Tune accuracy: 0.842
#
# -----------Epoch 7/20
# Train loss: 0.820. Tune loss: 0.602
# Train accuracy: 0.781. Tune accuracy: 0.841
#
# -----------Epoch 7/20
# Train loss: 1.035. Tune loss: 0.582
# Train accuracy: 0.750. Tune accuracy: 0.850
#
# -----------Epoch 7/20
# Train loss: 1.109. Tune loss: 0.539
# Train accuracy: 0.731. Tune accuracy: 0.857
#
# -----------Epoch 7/20
# Train loss: 0.984. Tune loss: 0.527
# Train accuracy: 0.700. Tune accuracy: 0.864
#
# -----------Epoch 7/20
# Train loss: 1.045. Tune loss: 0.524
# Train accuracy: 0.725. Tune accuracy: 0.867
#
# -----------Epoch 7/20
# Train loss: 0.750. Tune loss: 0.546
# Train accuracy: 0.769. Tune accuracy: 0.854
#
# -----------Epoch 7/20
# Train loss: 1.003. Tune loss: 0.551
# Train accuracy: 0.719. Tune accuracy: 0.860
#
# -----------Epoch 7/20
# Train loss: 0.960. Tune loss: 0.542
# Train accuracy: 0.731. Tune accuracy: 0.853
#
# -----------Epoch 7/20
# Train loss: 1.002. Tune loss: 0.561
# Train accuracy: 0.744. Tune accuracy: 0.856
#
# -----------Epoch 7/20
# Train loss: 1.127. Tune loss: 0.567
# Train accuracy: 0.706. Tune accuracy: 0.848
#
# -----------Epoch 7/20
# Train loss: 0.992. Tune loss: 0.542
# Train accuracy: 0.750. Tune accuracy: 0.849
#
# -----------Epoch 7/20
# Train loss: 1.075. Tune loss: 0.533
# Train accuracy: 0.731. Tune accuracy: 0.860
#
# -----------Epoch 7/20
# Train loss: 0.940. Tune loss: 0.520
# Train accuracy: 0.744. Tune accuracy: 0.867
#
# -----------Epoch 7/20
# Train loss: 0.830. Tune loss: 0.510
# Train accuracy: 0.725. Tune accuracy: 0.871
#
# -----------Epoch 7/20
# Train loss: 0.865. Tune loss: 0.537
# Train accuracy: 0.750. Tune accuracy: 0.866
#
# -----------Epoch 7/20
# Train loss: 0.848. Tune loss: 0.595
# Train accuracy: 0.781. Tune accuracy: 0.839
#
# -----------Epoch 7/20
# Train loss: 1.007. Tune loss: 0.569
# Train accuracy: 0.731. Tune accuracy: 0.847
#
# -----------Epoch 7/20
# Train loss: 1.008. Tune loss: 0.599
# Train accuracy: 0.694. Tune accuracy: 0.844
#
# -----------Epoch 7/20
# Train loss: 1.099. Tune loss: 0.632
# Train accuracy: 0.681. Tune accuracy: 0.827
#
# -----------Epoch 7/20
# Train loss: 1.096. Tune loss: 0.597
# Train accuracy: 0.675. Tune accuracy: 0.841
#
# -----------Epoch 7/20
# Train loss: 0.796. Tune loss: 0.603
# Train accuracy: 0.806. Tune accuracy: 0.842
#
# -----------Epoch 7/20
# Train loss: 0.742. Tune loss: 0.598
# Train accuracy: 0.794. Tune accuracy: 0.854
#
# -----------Epoch 7/20
# Train loss: 1.057. Tune loss: 0.587
# Train accuracy: 0.713. Tune accuracy: 0.849
#
# -----------Epoch 7/20
# Train loss: 0.959. Tune loss: 0.560
# Train accuracy: 0.756. Tune accuracy: 0.846
#
# -----------Epoch 7/20
# Train loss: 1.104. Tune loss: 0.571
# Train accuracy: 0.738. Tune accuracy: 0.857
#
# -----------Epoch 7/20
# Train loss: 0.951. Tune loss: 0.569
# Train accuracy: 0.750. Tune accuracy: 0.864
#
# -----------Epoch 7/20
# Train loss: 0.995. Tune loss: 0.609
# Train accuracy: 0.744. Tune accuracy: 0.844
#
# -----------Epoch 7/20
# Train loss: 0.995. Tune loss: 0.576
# Train accuracy: 0.725. Tune accuracy: 0.845
#
# -----------Epoch 7/20
# Train loss: 1.025. Tune loss: 0.580
# Train accuracy: 0.713. Tune accuracy: 0.852
#
# -----------Epoch 7/20
# Train loss: 0.869. Tune loss: 0.559
# Train accuracy: 0.742. Tune accuracy: 0.867
#
# -----------Epoch 8/20
# Train loss: 0.785. Tune loss: 0.584
# Train accuracy: 0.794. Tune accuracy: 0.849
#
# -----------Epoch 8/20
# Train loss: 1.027. Tune loss: 0.616
# Train accuracy: 0.756. Tune accuracy: 0.840
#
# -----------Epoch 8/20
# Train loss: 0.880. Tune loss: 0.605
# Train accuracy: 0.769. Tune accuracy: 0.828
#
# -----------Epoch 8/20
# Train loss: 0.981. Tune loss: 0.612
# Train accuracy: 0.750. Tune accuracy: 0.831
#
# -----------Epoch 8/20
# Train loss: 0.694. Tune loss: 0.608
# Train accuracy: 0.781. Tune accuracy: 0.840
#
# -----------Epoch 8/20
# Train loss: 0.864. Tune loss: 0.605
# Train accuracy: 0.781. Tune accuracy: 0.846
#
# -----------Epoch 8/20
# Train loss: 0.781. Tune loss: 0.586
# Train accuracy: 0.769. Tune accuracy: 0.855
#
# -----------Epoch 8/20
# Train loss: 1.065. Tune loss: 0.583
# Train accuracy: 0.725. Tune accuracy: 0.851
#
# -----------Epoch 8/20
# Train loss: 1.051. Tune loss: 0.590
# Train accuracy: 0.744. Tune accuracy: 0.845
#
# -----------Epoch 8/20
# Train loss: 1.107. Tune loss: 0.597
# Train accuracy: 0.700. Tune accuracy: 0.850
#
# -----------Epoch 8/20
# Train loss: 0.936. Tune loss: 0.593
# Train accuracy: 0.744. Tune accuracy: 0.838
#
# -----------Epoch 8/20
# Train loss: 0.787. Tune loss: 0.616
# Train accuracy: 0.756. Tune accuracy: 0.833
#
# -----------Epoch 8/20
# Train loss: 0.886. Tune loss: 0.599
# Train accuracy: 0.756. Tune accuracy: 0.846
#
# -----------Epoch 8/20
# Train loss: 0.921. Tune loss: 0.598
# Train accuracy: 0.750. Tune accuracy: 0.856
#
# -----------Epoch 8/20
# Train loss: 0.789. Tune loss: 0.604
# Train accuracy: 0.731. Tune accuracy: 0.854
#
# -----------Epoch 8/20
# Train loss: 1.125. Tune loss: 0.609
# Train accuracy: 0.731. Tune accuracy: 0.851
#
# -----------Epoch 8/20
# Train loss: 1.043. Tune loss: 0.578
# Train accuracy: 0.719. Tune accuracy: 0.854
#
# -----------Epoch 8/20
# Train loss: 1.188. Tune loss: 0.581
# Train accuracy: 0.738. Tune accuracy: 0.846
#
# -----------Epoch 8/20
# Train loss: 0.927. Tune loss: 0.572
# Train accuracy: 0.725. Tune accuracy: 0.843
#
# -----------Epoch 8/20
# Train loss: 0.982. Tune loss: 0.569
# Train accuracy: 0.738. Tune accuracy: 0.856
#
# -----------Epoch 8/20
# Train loss: 1.071. Tune loss: 0.595
# Train accuracy: 0.731. Tune accuracy: 0.848
#
# -----------Epoch 8/20
# Train loss: 1.174. Tune loss: 0.604
# Train accuracy: 0.706. Tune accuracy: 0.846
#
# -----------Epoch 8/20
# Train loss: 0.916. Tune loss: 0.588
# Train accuracy: 0.713. Tune accuracy: 0.858
#
# -----------Epoch 8/20
# Train loss: 1.084. Tune loss: 0.571
# Train accuracy: 0.719. Tune accuracy: 0.862
#
# -----------Epoch 8/20
# Train loss: 1.102. Tune loss: 0.569
# Train accuracy: 0.688. Tune accuracy: 0.864
#
# -----------Epoch 8/20
# Train loss: 0.926. Tune loss: 0.591
# Train accuracy: 0.731. Tune accuracy: 0.858
#
# -----------Epoch 8/20
# Train loss: 0.961. Tune loss: 0.638
# Train accuracy: 0.750. Tune accuracy: 0.848
#
# -----------Epoch 8/20
# Train loss: 0.808. Tune loss: 0.636
# Train accuracy: 0.781. Tune accuracy: 0.843
#
# -----------Epoch 8/20
# Train loss: 1.048. Tune loss: 0.583
# Train accuracy: 0.700. Tune accuracy: 0.859
#
# -----------Epoch 8/20
# Train loss: 1.245. Tune loss: 0.523
# Train accuracy: 0.656. Tune accuracy: 0.862
#
# -----------Epoch 8/20
# Train loss: 0.859. Tune loss: 0.515
# Train accuracy: 0.769. Tune accuracy: 0.858
#
# -----------Epoch 8/20
# Train loss: 1.172. Tune loss: 0.535
# Train accuracy: 0.700. Tune accuracy: 0.857
#
# -----------Epoch 8/20
# Train loss: 0.790. Tune loss: 0.558
# Train accuracy: 0.794. Tune accuracy: 0.848
# -----------Epoch 8/20
# Train loss: 0.887. Tune loss: 0.579
# Train accuracy: 0.744. Tune accuracy: 0.853
#
# -----------Epoch 8/20
# Train loss: 0.967. Tune loss: 0.560
# Train accuracy: 0.706. Tune accuracy: 0.866
#
# -----------Epoch 8/20
# Train loss: 1.138. Tune loss: 0.544
# Train accuracy: 0.706. Tune accuracy: 0.873
#
# -----------Epoch 8/20
# Train loss: 0.886. Tune loss: 0.531
# Train accuracy: 0.750. Tune accuracy: 0.868
#
# -----------Epoch 8/20
# Train loss: 1.099. Tune loss: 0.555
# Train accuracy: 0.694. Tune accuracy: 0.856
#
# -----------Epoch 8/20
# Train loss: 0.889. Tune loss: 0.544
# Train accuracy: 0.769. Tune accuracy: 0.858
#
# -----------Epoch 8/20
# Train loss: 1.139. Tune loss: 0.521
# Train accuracy: 0.694. Tune accuracy: 0.869
#
# -----------Epoch 8/20
# Train loss: 0.943. Tune loss: 0.542
# Train accuracy: 0.729. Tune accuracy: 0.865
#
# -----------Epoch 9/20
# Train loss: 0.996. Tune loss: 0.528
# Train accuracy: 0.750. Tune accuracy: 0.863
#
# -----------Epoch 9/20
# Train loss: 0.850. Tune loss: 0.520
# Train accuracy: 0.738. Tune accuracy: 0.860
#
# -----------Epoch 9/20
# Train loss: 0.946. Tune loss: 0.528
# Train accuracy: 0.700. Tune accuracy: 0.863
#
# -----------Epoch 9/20
# Train loss: 1.009. Tune loss: 0.522
# Train accuracy: 0.756. Tune accuracy: 0.872
#
# -----------Epoch 9/20
# Train loss: 0.670. Tune loss: 0.545
# Train accuracy: 0.812. Tune accuracy: 0.867
#
# -----------Epoch 9/20
# Train loss: 0.817. Tune loss: 0.551
# Train accuracy: 0.738. Tune accuracy: 0.869
#
# -----------Epoch 9/20
# Train loss: 1.043. Tune loss: 0.577
# Train accuracy: 0.762. Tune accuracy: 0.860
#
# -----------Epoch 9/20
# Train loss: 0.763. Tune loss: 0.586
# Train accuracy: 0.756. Tune accuracy: 0.855
#
# -----------Epoch 9/20
# Train loss: 0.779. Tune loss: 0.594
# Train accuracy: 0.787. Tune accuracy: 0.853
#
# -----------Epoch 9/20
# Train loss: 0.944. Tune loss: 0.595
# Train accuracy: 0.725. Tune accuracy: 0.854
#
# -----------Epoch 9/20
# Train loss: 0.680. Tune loss: 0.599
# Train accuracy: 0.781. Tune accuracy: 0.864
#
# -----------Epoch 9/20
# Train loss: 1.099. Tune loss: 0.609
# Train accuracy: 0.744. Tune accuracy: 0.860
#
# -----------Epoch 9/20
# Train loss: 0.981. Tune loss: 0.608
# Train accuracy: 0.744. Tune accuracy: 0.858
#
# -----------Epoch 9/20
# Train loss: 0.802. Tune loss: 0.583
# Train accuracy: 0.750. Tune accuracy: 0.867
#
# -----------Epoch 9/20
# Train loss: 0.548. Tune loss: 0.565
# Train accuracy: 0.787. Tune accuracy: 0.870
#
# -----------Epoch 9/20
# Train loss: 0.679. Tune loss: 0.561
# Train accuracy: 0.819. Tune accuracy: 0.877
#
# -----------Epoch 9/20
# Train loss: 0.930. Tune loss: 0.548
# Train accuracy: 0.769. Tune accuracy: 0.874
#
# -----------Epoch 9/20
# Train loss: 0.996. Tune loss: 0.560
# Train accuracy: 0.744. Tune accuracy: 0.863
#
# -----------Epoch 9/20
# Train loss: 0.757. Tune loss: 0.554
# Train accuracy: 0.800. Tune accuracy: 0.870
#
# -----------Epoch 9/20
# Train loss: 0.839. Tune loss: 0.556
# Train accuracy: 0.769. Tune accuracy: 0.866
#
# -----------Epoch 9/20
# Train loss: 0.978. Tune loss: 0.552
# Train accuracy: 0.775. Tune accuracy: 0.869
#
# -----------Epoch 9/20
# Train loss: 1.028. Tune loss: 0.561
# Train accuracy: 0.744. Tune accuracy: 0.861
#
# -----------Epoch 9/20
# Train loss: 0.923. Tune loss: 0.576
# Train accuracy: 0.800. Tune accuracy: 0.860
#
# -----------Epoch 9/20
# Train loss: 1.274. Tune loss: 0.589
# Train accuracy: 0.675. Tune accuracy: 0.864
#
# -----------Epoch 9/20
# Train loss: 0.958. Tune loss: 0.617
# Train accuracy: 0.744. Tune accuracy: 0.848
#
# -----------Epoch 9/20
# Train loss: 0.934. Tune loss: 0.609
# Train accuracy: 0.762. Tune accuracy: 0.851
#
# -----------Epoch 9/20
# Train loss: 1.158. Tune loss: 0.609
# Train accuracy: 0.706. Tune accuracy: 0.855
#
# -----------Epoch 9/20
# Train loss: 0.854. Tune loss: 0.587
# Train accuracy: 0.794. Tune accuracy: 0.864
#
# -----------Epoch 9/20
# Train loss: 0.801. Tune loss: 0.599
# Train accuracy: 0.787. Tune accuracy: 0.864
#
# -----------Epoch 9/20
# Train loss: 0.887. Tune loss: 0.614
# Train accuracy: 0.769. Tune accuracy: 0.853
#
# -----------Epoch 9/20
# Train loss: 0.913. Tune loss: 0.623
# Train accuracy: 0.756. Tune accuracy: 0.851
#
# -----------Epoch 9/20
# Train loss: 0.875. Tune loss: 0.579
# Train accuracy: 0.750. Tune accuracy: 0.855
#
# -----------Epoch 9/20
# Train loss: 0.882. Tune loss: 0.557
# Train accuracy: 0.731. Tune accuracy: 0.858
#
# -----------Epoch 9/20
# Train loss: 1.051. Tune loss: 0.533
# Train accuracy: 0.731. Tune accuracy: 0.867
#
# -----------Epoch 9/20
# Train loss: 0.836. Tune loss: 0.518
# Train accuracy: 0.756. Tune accuracy: 0.867
#
# -----------Epoch 9/20
# Train loss: 0.749. Tune loss: 0.537
# Train accuracy: 0.794. Tune accuracy: 0.859
#
# -----------Epoch 9/20
# Train loss: 1.011. Tune loss: 0.555
# Train accuracy: 0.713. Tune accuracy: 0.863
#
# -----------Epoch 9/20
# Train loss: 0.734. Tune loss: 0.601
# Train accuracy: 0.787. Tune accuracy: 0.852
#
# -----------Epoch 9/20
# Train loss: 0.874. Tune loss: 0.617
# Train accuracy: 0.762. Tune accuracy: 0.850
#
# -----------Epoch 9/20
# Train loss: 0.734. Tune loss: 0.584
# Train accuracy: 0.775. Tune accuracy: 0.862
#
# -----------Epoch 9/20
# Train loss: 0.908. Tune loss: 0.617
# Train accuracy: 0.769. Tune accuracy: 0.864
#
# -----------Epoch 10/20
# Train loss: 0.813. Tune loss: 0.604
# Train accuracy: 0.787. Tune accuracy: 0.853
#
# -----------Epoch 10/20
# Train loss: 0.897. Tune loss: 0.584
# Train accuracy: 0.738. Tune accuracy: 0.856
#
# -----------Epoch 10/20
# Train loss: 0.797. Tune loss: 0.590
# Train accuracy: 0.762. Tune accuracy: 0.860
#
# -----------Epoch 10/20
# Train loss: 0.959. Tune loss: 0.566
# Train accuracy: 0.731. Tune accuracy: 0.873
#
# -----------Epoch 10/20
# Train loss: 1.030. Tune loss: 0.552
# Train accuracy: 0.731. Tune accuracy: 0.871
#
# -----------Epoch 10/20
# Train loss: 0.960. Tune loss: 0.600
# Train accuracy: 0.750. Tune accuracy: 0.852
#
# -----------Epoch 10/20
# Train loss: 0.890. Tune loss: 0.613
# Train accuracy: 0.750. Tune accuracy: 0.854
#
# -----------Epoch 10/20
# Train loss: 0.921. Tune loss: 0.632
# Train accuracy: 0.794. Tune accuracy: 0.837
#
# -----------Epoch 10/20
# Train loss: 0.761. Tune loss: 0.648
# Train accuracy: 0.762. Tune accuracy: 0.836
#
# -----------Epoch 10/20
# Train loss: 0.856. Tune loss: 0.599
# Train accuracy: 0.800. Tune accuracy: 0.853
#
# -----------Epoch 10/20
# Train loss: 0.857. Tune loss: 0.575
# Train accuracy: 0.744. Tune accuracy: 0.860
#
# -----------Epoch 10/20
# Train loss: 0.860. Tune loss: 0.573
# Train accuracy: 0.800. Tune accuracy: 0.863
#
# -----------Epoch 10/20
# Train loss: 0.867. Tune loss: 0.578
# Train accuracy: 0.794. Tune accuracy: 0.853
#
# -----------Epoch 10/20
# Train loss: 0.813. Tune loss: 0.563
# Train accuracy: 0.787. Tune accuracy: 0.866
#
# -----------Epoch 10/20
# Train loss: 0.727. Tune loss: 0.576
# Train accuracy: 0.800. Tune accuracy: 0.864
#
# -----------Epoch 10/20
# Train loss: 0.784. Tune loss: 0.641
# Train accuracy: 0.769. Tune accuracy: 0.860
#
# -----------Epoch 10/20
# Train loss: 0.884. Tune loss: 0.665
# Train accuracy: 0.781. Tune accuracy: 0.853
#
# -----------Epoch 10/20
# Train loss: 0.996. Tune loss: 0.651
# Train accuracy: 0.750. Tune accuracy: 0.855
#
# -----------Epoch 10/20
# Train loss: 1.120. Tune loss: 0.633
# Train accuracy: 0.669. Tune accuracy: 0.851
#
# -----------Epoch 10/20
# Train loss: 0.847. Tune loss: 0.628
# Train accuracy: 0.744. Tune accuracy: 0.852
#
# -----------Epoch 10/20
# Train loss: 1.010. Tune loss: 0.629
# Train accuracy: 0.756. Tune accuracy: 0.864
#
# -----------Epoch 10/20
# Train loss: 0.794. Tune loss: 0.587
# Train accuracy: 0.769. Tune accuracy: 0.874
#
# -----------Epoch 10/20
# Train loss: 0.761. Tune loss: 0.584
# Train accuracy: 0.769. Tune accuracy: 0.865
#
# -----------Epoch 10/20
# Train loss: 0.847. Tune loss: 0.618
# Train accuracy: 0.744. Tune accuracy: 0.860
#
# -----------Epoch 10/20
# Train loss: 0.904. Tune loss: 0.674
# Train accuracy: 0.781. Tune accuracy: 0.850
#
# -----------Epoch 10/20
# Train loss: 1.075. Tune loss: 0.739
# Train accuracy: 0.738. Tune accuracy: 0.842
#
# -----------Epoch 10/20
# Train loss: 1.045. Tune loss: 0.651
# Train accuracy: 0.719. Tune accuracy: 0.855
#
# -----------Epoch 10/20
# Train loss: 0.987. Tune loss: 0.592
# Train accuracy: 0.781. Tune accuracy: 0.863
#
# -----------Epoch 10/20
# Train loss: 0.864. Tune loss: 0.593
# Train accuracy: 0.762. Tune accuracy: 0.864
#
# -----------Epoch 10/20
# Train loss: 0.910. Tune loss: 0.598
# Train accuracy: 0.744. Tune accuracy: 0.866
#
# -----------Epoch 10/20
# Train loss: 0.892. Tune loss: 0.610
# Train accuracy: 0.800. Tune accuracy: 0.863
# -----------Epoch 10/20
# Train loss: 0.945. Tune loss: 0.654
# Train accuracy: 0.744. Tune accuracy: 0.859
#
# -----------Epoch 10/20
# Train loss: 1.176. Tune loss: 0.698
# Train accuracy: 0.681. Tune accuracy: 0.858
#
# -----------Epoch 10/20
# Train loss: 1.099. Tune loss: 0.784
# Train accuracy: 0.725. Tune accuracy: 0.849
#
# -----------Epoch 10/20
# Train loss: 0.760. Tune loss: 0.740
# Train accuracy: 0.756. Tune accuracy: 0.839
#
# -----------Epoch 10/20
# Train loss: 1.042. Tune loss: 0.745
# Train accuracy: 0.725. Tune accuracy: 0.839
#
# -----------Epoch 10/20
# Train loss: 0.706. Tune loss: 0.754
# Train accuracy: 0.769. Tune accuracy: 0.827
#
# -----------Epoch 10/20
# Train loss: 1.273. Tune loss: 0.674
# Train accuracy: 0.675. Tune accuracy: 0.838
#
# -----------Epoch 10/20
# Train loss: 1.020. Tune loss: 0.694
# Train accuracy: 0.713. Tune accuracy: 0.835
#
# -----------Epoch 10/20
# Train loss: 0.954. Tune loss: 0.611
# Train accuracy: 0.731. Tune accuracy: 0.852
#
# -----------Epoch 10/20
# Train loss: 0.961. Tune loss: 0.605
# Train accuracy: 0.679. Tune accuracy: 0.857
#
# -----------Epoch 11/20
# Train loss: 0.675. Tune loss: 0.616
# Train accuracy: 0.800. Tune accuracy: 0.852
#
# -----------Epoch 11/20
# Train loss: 0.948. Tune loss: 0.643
# Train accuracy: 0.694. Tune accuracy: 0.849
#
# -----------Epoch 11/20
# Train loss: 0.742. Tune loss: 0.618
# Train accuracy: 0.775. Tune accuracy: 0.858
#
# -----------Epoch 11/20
# Train loss: 0.869. Tune loss: 0.610
# Train accuracy: 0.756. Tune accuracy: 0.856
#
# -----------Epoch 11/20
# Train loss: 1.030. Tune loss: 0.625
# Train accuracy: 0.738. Tune accuracy: 0.852
#
# -----------Epoch 11/20
# Train loss: 0.938. Tune loss: 0.603
# Train accuracy: 0.750. Tune accuracy: 0.850
#
# -----------Epoch 11/20
# Train loss: 0.984. Tune loss: 0.606
# Train accuracy: 0.750. Tune accuracy: 0.850
#
# -----------Epoch 11/20
# Train loss: 1.040. Tune loss: 0.563
# Train accuracy: 0.725. Tune accuracy: 0.861
#
# -----------Epoch 11/20
# Train loss: 0.718. Tune loss: 0.543
# Train accuracy: 0.819. Tune accuracy: 0.880
#
# -----------Epoch 11/20
# Train loss: 0.863. Tune loss: 0.513
# Train accuracy: 0.762. Tune accuracy: 0.883
#
# -----------Epoch 11/20
# Train loss: 0.888. Tune loss: 0.494
# Train accuracy: 0.756. Tune accuracy: 0.884
#
# -----------Epoch 11/20
# Train loss: 1.022. Tune loss: 0.528
# Train accuracy: 0.731. Tune accuracy: 0.876
#
# -----------Epoch 11/20
# Train loss: 0.944. Tune loss: 0.548
# Train accuracy: 0.756. Tune accuracy: 0.865
#
# -----------Epoch 11/20
# Train loss: 1.011. Tune loss: 0.568
# Train accuracy: 0.725. Tune accuracy: 0.857
#
# -----------Epoch 11/20
# Train loss: 0.953. Tune loss: 0.568
# Train accuracy: 0.744. Tune accuracy: 0.853
#
# -----------Epoch 11/20
# Train loss: 0.993. Tune loss: 0.591
# Train accuracy: 0.725. Tune accuracy: 0.855
#
# -----------Epoch 11/20
# Train loss: 0.883. Tune loss: 0.600
# Train accuracy: 0.781. Tune accuracy: 0.855
#
# -----------Epoch 11/20
# Train loss: 0.861. Tune loss: 0.586
# Train accuracy: 0.738. Tune accuracy: 0.861
#
# -----------Epoch 11/20
# Train loss: 0.811. Tune loss: 0.572
# Train accuracy: 0.731. Tune accuracy: 0.853
#
# -----------Epoch 11/20
# Train loss: 0.860. Tune loss: 0.562
# Train accuracy: 0.750. Tune accuracy: 0.855
#
# -----------Epoch 11/20
# Train loss: 0.980. Tune loss: 0.540
# Train accuracy: 0.756. Tune accuracy: 0.862
#
# -----------Epoch 11/20
# Train loss: 0.808. Tune loss: 0.525
# Train accuracy: 0.794. Tune accuracy: 0.858
#
# -----------Epoch 11/20
# Train loss: 0.897. Tune loss: 0.528
# Train accuracy: 0.756. Tune accuracy: 0.866
#
# -----------Epoch 11/20
# Train loss: 0.836. Tune loss: 0.565
# Train accuracy: 0.806. Tune accuracy: 0.862
#
# -----------Epoch 11/20
# Train loss: 0.796. Tune loss: 0.584
# Train accuracy: 0.775. Tune accuracy: 0.862
#
# -----------Epoch 11/20
# Train loss: 0.876. Tune loss: 0.590
# Train accuracy: 0.731. Tune accuracy: 0.858
#
# -----------Epoch 11/20
# Train loss: 0.865. Tune loss: 0.569
# Train accuracy: 0.794. Tune accuracy: 0.854
#
# -----------Epoch 11/20
# Train loss: 0.819. Tune loss: 0.543
# Train accuracy: 0.794. Tune accuracy: 0.858
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-bb912b2561a5> in <module>()
#      63                 with torch.no_grad(): # reduces memory usage - we dont need to calculate the gradients in evaluation mode
#      64
# ---> 65                     for images, labels in tuneloader:
#      66
#      67                         # Move images and labels tensors to the default device (GPU if available)
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     262         if self.num_workers == 0:  # same-process loading
#     263             indices = next(self.sample_iter)  # may raise StopIteration
# --> 264             batch = self.collate_fn([self.dataset[i] for i in indices])
#     265             if self.pin_memory:
#     266                 batch = pin_memory_batch(batch)
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     262         if self.num_workers == 0:  # same-process loading
#     263             indices = next(self.sample_iter)  # may raise StopIteration
# --> 264             batch = self.collate_fn([self.dataset[i] for i in indices])
#     265             if self.pin_memory:
#     266                 batch = pin_memory_batch(batch)
#
# /opt/conda/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/datasets/folder.py in __getitem__(self, index)
#      99         """
#     100         path, target = self.samples[index]
# --> 101         sample = self.loader(path)
#     102         if self.transform is not None:
#     103             sample = self.transform(sample)
#
# /opt/conda/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/datasets/folder.py in default_loader(path)
#     145         return accimage_loader(path)
#     146     else:
# --> 147         return pil_loader(path)
#     148
#     149
#
# /opt/conda/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/datasets/folder.py in pil_loader(path)
#     128     with open(path, 'rb') as f:
#     129         img = Image.open(f)
# --> 130         return img.convert('RGB')
#     131
#     132
#
# /opt/conda/lib/python3.6/site-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#     890         """
#     891
# --> 892         self.load()
#     893
#     894         if not mode and self.mode == "P":
#
# /opt/conda/lib/python3.6/site-packages/PIL/ImageFile.py in load(self)
#     233
#     234                             b = b + s
# --> 235                             n, err_code = decoder.decode(b)
#     236                             if n < 0:
#     237                                 break
#
# KeyboardInterrupt:

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.plot(train_losses, label='Training loss');
plt.plot(tune_losses, label='Tuning loss');
plt.legend(frameon=False)

# %%
plt.plot(train_accuracy, label='Training accuracy');
plt.plot(tune_accuracy, label='Tuning accuracy');
plt.legend(frameon=False)

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# -- TEST THE MODEL

test_loss = 0
accuracy = 0
model.eval() # set model in evaluation mode

with torch.no_grad(): # reduces memory usage - we dont need to calculate the gradients in evaluation mode
                    
    for images, labels in testloader:

        # Move images and labels tensors to the default device (GPU if available)
        images = images.to(device)
        labels = labels.to(device)

        # Calculate the loss
        log_ps = model(images) # log of probability
        loss = criterion(log_ps, labels)
        test_loss += loss.item()

        # calculate the accuracy
        ps = torch.exp(log_ps) # get the actual probability
        top_p, top_class = ps.topk(1, dim=1) # top probabilities and classes

        equals = top_class == labels.view(*top_class.shape) # check how many images which have the correct classification. 
        # That *top_class.shape is passing all of the items in the top_class.shape into the view function call as separate arguments, without us even needing to know how many arguments are in the list. For example if the top_class has a shape say (32, 1), so *top_class.shape will pass 32, 1 to view function. Now this is as good as passing (top_class.shape[0],top_class.shape[1]). labels.view(top_class.shape[0],top_class.shape[1]) is equal to labels.view(*top_class.shape). The labels.view(*top_class.shape) is very useful because we dont have to know the exact shape for us to reshape them, we just use * and it will pack everything into a list and pass on to the view function for reshaping

        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
        # after getting the top_class of the top_probability from torch.exp(output), we equal the top_class with the images labels (targets) to check if they match or not. The result from this equality is binary values [0,1]. Does this mean that 1 refers to class-label matching and 0 refers to class-label mismatching? Yes    

print(f"Test loss: {test_loss/len(testloader):.3f}.. "
      f"Test accuracy: {accuracy/len(testloader):.3f}")
# Out:
# Test loss: 0.610.. Test accuracy: 0.836

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# Define the classifier definitions
model.class_to_idx = train_data.class_to_idx

# Save the checkpoint/model 
checkpoint = {'arch': 'vgg16',
              'state_dict': model.state_dict(),
              'optimizer': optimizer.state_dict(),
              'class_to_idx': train_data.class_to_idx,
              'epochs': epochs,
              'learning_rate': optimizer.state_dict()['param_groups'][0]['lr'],
              'input_size': 25088,
              'output_size': 102,
              'hidden_layers': 512,
              'state_dict': model.state_dict()}

name = 'checkpoint.pth'
torch.save(checkpoint, name)

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
name = 'checkpoint.pth'
#model = torch.load(name)
#model.keys()

# %%
# Loading the model and rebuilding the model

def load_model(filepath):
    
    # Run on GPU if possible
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    
    # Assign the model data into a variable
    checkpoint = torch.load(filepath)
    print(checkpoint.keys())

    # Assign the name of the pretrained model as string
    new_model = models.vgg16(pretrained=True) # How to create from parameter?

    # Rebuild the model
    classifier = nn.Sequential(OrderedDict([
        ('fc1', nn.Linear(checkpoint['input_size'], checkpoint['hidden_layers'])),
        ('relu1', nn.ReLU()),
        ('do1', nn.Dropout(0.2)),
        ('fc2', nn.Linear(checkpoint['hidden_layers'], checkpoint['output_size'])),
        ('output', nn.LogSoftmax(dim=1))
        ]))

    # Define new_model classifier
    new_model.classifier = classifier
    
    # Define new_model weights
    new_model.load_state_dict(checkpoint['state_dict'])
    
    # Define model class_to_dict
    new_model.class_to_idx = checkpoint['class_to_idx']
    #print(new_model.class_to_idx)

    # Send to the GPU?
    new_model.to(device)

    # Loading model to device
    new_model.to(device)
    
    return new_model 

new_model = load_model(name)
print(new_model)
# Out:
# dict_keys(['arch', 'state_dict', 'optimizer', 'class_to_idx', 'epochs', 'learning_rate', 'input_size', 'output_size', 'hidden_layers'])
# {'1': 0, '10': 1, '100': 2, '101': 3, '102': 4, '11': 5, '12': 6, '13': 7, '14': 8, '15': 9, '16': 10, '17': 11, '18': 12, '19': 13, '2': 14, '20': 15, '21': 16, '22': 17, '23': 18, '24': 19, '25': 20, '26': 21, '27': 22, '28': 23, '29': 24, '3': 25, '30': 26, '31': 27, '32': 28, '33': 29, '34': 30, '35': 31, '36': 32, '37': 33, '38': 34, '39': 35, '4': 36, '40': 37, '41': 38, '42': 39, '43': 40, '44': 41, '45': 42, '46': 43, '47': 44, '48': 45, '49': 46, '5': 47, '50': 48, '51': 49, '52': 50, '53': 51, '54': 52, '55': 53, '56': 54, '57': 55, '58': 56, '59': 57, '6': 58, '60': 59, '61': 60, '62': 61, '63': 62, '64': 63, '65': 64, '66': 65, '67': 66, '68': 67, '69': 68, '7': 69, '70': 70, '71': 71, '72': 72, '73': 73, '74': 74, '75': 75, '76': 76, '77': 77, '78': 78, '79': 79, '8': 80, '80': 81, '81': 82, '82': 83, '83': 84, '84': 85, '85': 86, '86': 87, '87': 88, '88': 89, '89': 90, '9': 91, '90': 92, '91': 93, '92': 94, '93': 95, '94': 96, '95': 97, '96': 98, '97': 99, '98': 100, '99': 101}
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=512, bias=True)
#     (relu1): ReLU()
#     (do1): Dropout(p=0.2)
#     (fc2): Linear(in_features=512, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
# label for classification
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

#print(cat_to_name)

# %%
# image_path = 'flowers/test/12/image_03994.jpg' # Works Colts foot :D 
# image_path = 'flowers/test/16/image_06657.jpg' # Globe flower predicts rose
# image_path = 'flowers/test/19/image_06170.jpg' # Works baloon flower
image_path = 'flowers/test/83/image_01774.jpg' # Works hibiscus
# image_path = 'flowers/test/83/image_01742.jpg' # Works Hibiscus :D

# %%
def process_image(image_path):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # Open 1 image
    img = Image.open(image_path)
    #print(f'Image org size: {img.size}')
    #plt.imshow(img)
    #plt.show()
        
    # Scale
    width, height = img.size
    #print(f'Width: {width}') # [0]
    #print(f'Height: {height}') # [1]
    
    smallest_len = 256
    ratio = max(smallest_len/width, smallest_len/height)
    rW, rH = round(width*ratio), round(height*ratio)
    #SIZE=round(max(width*ratio, height*ratio)) # also works fine

    img.thumbnail((rW, rH), Image.ANTIALIAS)
    #print(f'Image thumbnail: {img.size}')
    
    # Crop
    crop_size = 224 
    width, height = img.size
    left = (width - crop_size)/2 # zero is in the top left corner
    top = (height - crop_size)/2
    right = left + crop_size
    bottom = top + crop_size
    
    img = img.crop((left, top, right, bottom))
    #print(f'Image size: {img.size}')
    
    #plt.imshow(img)
    #plt.show()
    
    # Change color channels (typically 0-255, but model expects floats 0-1)
    np_img = np.array(img)/255 # Normalize manually
    #print(f'np_img size: {np_img.size}')
    #print(f'np_img shape: {np_img.shape}')
    
    # Normalize the color channels
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    np_img = (np_img - mean)/std
    #print(f'np_img size: {np_img.size}')
    #print(f'np_img shape: {np_img.shape}')
    
    #plt.imshow(np.clip(np_img, 0, 1))
    
    # Transpose the color channels (pytorch expects 
    # color channels to be the first dimension, in PIL 
    # image and np array its the 3rd)
    processed_img = np_img.transpose(2,0,1)
    #print(f'processed_img size: {processed_img.size}')
    
    # Modify the output to a tensor
    tensor_img = torch.from_numpy(processed_img)
    #print(f'tensor_img shape: {tensor_img.shape}')
    
    return tensor_img

image = process_image(image_path)
print(f'Process Output shape: {image.shape}')
# Out:
# Process Output shape: torch.Size([3, 224, 224])

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    #print(f'Image size 1: {image.size}')
    
    if ax is None:
        fig, ax = plt.subplots()

    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    #image = image.numpy()[0].transpose((1, 2, 0))
    image = image.permute(1, 2, 0).numpy() 
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    ax.imshow(image)

    return ax

#imshow(image);

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    
     # Set the model in evaluation mode
    model.eval()

    # Process Image - From jpeg to Tensor
    #print(img.size())
    img = process_image(image_path);
    #print(img.size())

    # Send tensor to device
    #print(img.is_cuda)
    img = img.to(device=device)
    #print(img.is_cuda)

    # No need to Flatten Tensor - but need to add an dimension
    #print(img.size())
    img = img.unsqueeze(0).float()
    #print(f'Image output size: {img.size()}')

    # Prediction - Run feed forward with current 
    # weights to make a prediction
    # Turn off auto_grad
    with torch.no_grad():
        output = model.forward(img)
        
    # Convert from log_probability to probability
    probs = torch.exp(output)

    # Pick the top 5 highest probabilities
    top_probs, top_idx = torch.topk(probs, topk)
    #print(top_probs, top_idx)

    return top_probs[0].tolist(), top_idx[0].tolist()

predict(image_path, new_model)
# Out:
# ([0.9850664734840393,
#   0.014928913675248623,
#   1.8760496232061996e-06,
#   1.3608092785943882e-06,
#   7.96772951616731e-07],
#  [84, 83, 75, 72, 13])

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# Display an image along with the top 5 classes
def display_solution(image_path, model):
    
    import pandas as pd 
    fig, (ax1, ax2) = plt.subplots(figsize=(6,10), ncols=1, nrows=2)

    # Display an image
    img = process_image(image_path)
    imshow(img, ax=ax1); # Plots flower

    # Display model predictions
    top_probs, top_classes = predict(image_path, new_model)
    #print(f'Top probabilities: {top_probs}\nTop indexes: {top_classes}')

    # From model_idx find flower_idx
    class_to_idx = model.class_to_idx
    idx_to_class = {value : key for (key, value) in class_to_idx.items()}

    flower_idx = []
    for i in top_classes:
        model_idx = i
        flower_idx.append(idx_to_class[model_idx])
    #print(f'Flower_idx: {flower_idx}')

    # From flower_idx find flower_name
    flower_name = []
    for idx, val in enumerate(flower_idx):
        #print(idx, val)
        #print(cat_to_name[val])
        flower_name.append(cat_to_name[val])

    #print(flower_name)

    # Create a dictionary/df of the top 5 highest probabilities and the corresponding flower name
    prob_dict = dict(zip(flower_name, top_probs))
    #print(prob_dict)

    #print(prob_dict)
    df = pd.DataFrame.from_dict(prob_dict, orient='index', columns = ['probability'])

    # Barplot predictions
    df.plot(kind = 'barh', ax=ax2);
    plt.title('Top Predictions');
    plt.gca().invert_yaxis()

    return 
    
display_solution(image_path, new_model);
